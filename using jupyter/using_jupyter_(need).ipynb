# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # 1 What to expect in this chapter

# %% [markdown]
# # 2 Getting ready

# %% [markdown]
# # 3 Getting started with Jupyter

# %% [markdown]
# ## 3.1 It is all about running cells

# %% [markdown]
# ## 3.2 A traditional start

# %%
a = 10000000
b = 1
c = a + b
print(c)
# Out:
# 10000001

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# # 4 All about Markdown

# %% [markdown]
# ## 4.1 Rendering Markdown cells

# %% [markdown]
# The ships hung in the sky in much the same way that bricks don’t.

# %% [markdown]
# ## 4.2 Some basic syntax

# %% [markdown]
# **bold**
# *italic*
# ***all bold and italic***
# <sup>superscript<sup>
# <sub>subscript<sub>

# %% [markdown]
# ## 4.3 Headings

# %% [markdown]
# # The Largest Heading
# ## The Second-Largest Heading
# ### The Third-Largest Heading
# #### The Fourth-Largest Heading

# %% [markdown]
# ## 4.4 Displaying Code

# %% [markdown]
# `print('Hello World')`

# %% [markdown]
# ```python
# print('Hello World!')
# ```

# %% [markdown]
# ## 4.5 Links

# %% [markdown]
# [SP2273 Website](https://www.youtube.com/watch?v=dQw4w9WgXcQ)

# %% [markdown]
# ## 4.6 Images

# %% [markdown]
# ![](https://www.shutterstock.com/image-illustration/3d-illustrationghost-woman-face-dark-260nw-777099841.jpg)

# %% [markdown]
# ![AA009 (3).jpg](attachment:7d88296c-e26d-428e-88e6-76e9b7a2a0f5.jpg)

# %% [markdown]
# ## 4.7 Tables

# %% [markdown]
# | A    |  B   |    C |
# | :--- | :--: | ---: |
# | a1   |  b1  |   c1 |
# | a2   |  b2  |   c2 |
# | a3   |  b3  |   c3 |

# %% [markdown]
# ## 4.8 Lists

# %% [markdown]
# - Master Yoda
# 1. Luke SkyWalker
# 2. Anakin Skywalker
#       1. Was a Jedi that became a Baddie
#       - Is famous for saying 'Luke, I am your father'

# %% [markdown]
# ## 4.9 Equations

# %% [markdown]
# Given the equation $\sqrt{b^2-4ac}$ ...

# %% [markdown]
# An equation to keep in mind is ... $$
# x = \dfrac{-b \pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# ## Footnotes
