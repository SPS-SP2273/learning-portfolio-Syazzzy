# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ### Things to note

# %% [markdown]
# | **Long form** | **Abbreviation** |
# |:-------------:|:----------------:|
# |     color     |         c        |
# |   linestyle   |        ls        |
# |   linewidth   |        lw        |

# %% [markdown]
# **1. Both the following lines produce the same result**

# %%
plt.plot(x, y_2, color='red', linestyle='dashed', linewidth=2)

# %%
plt.plot(x, y_2, c='red', ls='dashed', lw=2)

# %% [markdown]
# **2. You will see an output even if you omit `plt.show()`**

# %% [markdown]
# **3. The plotting functions usually have default values for the styling parameters**

# %%
plt.plot(x, y_1, y_2)
# Out:
# [<matplotlib.lines.Line2D at 0x20cbb982550>,
#  <matplotlib.lines.Line2D at 0x20cbbbaa710>]

# %% [markdown]
# **4. You can split the arguments into separate lines to improve readability.**

# %% [markdown]
# ```ruby
# plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)
# ```

# %% [markdown]
# ```ruby
# plt.plot(x, y_1, label='Y values',
#            color='red', linestyle='dashed')
# ```

# %% [markdown]
# ## 1.2 Adding another plot

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
import numpy as np

x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %% [markdown]
# ### Things to note

# %%
x = np.linspace(0, 6, 100) # using np.linspace() improves the plot
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150) # the file simple-plot.png is saved

# %% [markdown]
# **Windows**

# %% [markdown]
# ```ruby
# plt.savefig('C://Desktop/simple-plot.png', dpi=150)
# ```

# %% [markdown]
# **macOS**

# %% [markdown]
# ```ruby
# plt.savefig('~/Desktop/simple-plot.png', dpi=150)
# ```

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
plt.style.use('fivethirtyeight') #  Matplotlib offers some standard style templates 

data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)

plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey') # add a horizontal line at the zero value to highlight the trend shown by the data

plt.ylim([-8, 8])

# add labels and legend
plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %% [markdown]
#  To enable this, just run plt.xkcd() instead of setting a style.

# %% [markdown]
# ```ruby
# plt.xkcd()
# ```

# %% [markdown]
# ### Resetting styles

# %% [markdown]
# If you want to reset things, set the default style using:

# %% [markdown]
# ```ruby
# plt.style.use('default')
# ```
